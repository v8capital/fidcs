# %%
import pandas as pd

# %%
csv = []
for i in range(2, 5):
    csv.append(pd.read_csv(f'FIDCS_2025_0{i}_01.csv', delimiter=';'))

len(csv)
# Out:
# 3

# %%
cols_to_verify = ["PL Total", "PL Sênior", "PL Subordinada Jr", "Subordinação (%)",
                  "Subordinação Jr (%)", "PDD Total (PL%)", "Vencidos Total (PL%)",
                  "Prazo Médio", "Taxa Média", "Concentração Maior Cedente (PL%)",
                  "Concentração Maior Sacado (PL%)", "Concentração 10 Maiores Cedentes (PL%)",
                  "Concentração 10 Maiores Sacados (PL%)", "Quantidade de Cedentes",
                  "Quantidade de Sacados", "Liquidados Total (PL%)", "Duplicata (PL%)",
                  "Recompra (PL%)", "Volume Operado (PL%)", "Caixa/Disponibilidades (%PL)"]

# %%
fidc = "SIFRAPLUS"

# %%
csv[0].loc[csv[0]["FIDC"] == fidc, cols_to_verify]

# Fev
# Out:
#         PL Total     PL Sênior  PL Subordinada Jr  Subordinação (%)  \
# 21  9.413889e+08  5.394456e+08       2.925969e+08         42.696832
#
#     Subordinação Jr (%)  PDD Total (PL%)  Vencidos Total (PL%)  Prazo Médio  \
# 21            31.081402         2.701124              7.596936          NaN
#
#     Taxa Média  Concentração Maior Cedente (PL%)  \
# 21         NaN                          5.575581
#
#     Concentração Maior Sacado (PL%)  Concentração 10 Maiores Cedentes (PL%)  \
# 21                         3.075537                               33.248659
#
#     Concentração 10 Maiores Sacados (PL%)  Quantidade de Cedentes  \
# 21                              17.477694                   341.0
#
#     Quantidade de Sacados  Liquidados Total (PL%)  Duplicata (PL%)  \
# 21                10196.0                     NaN        84.299351
#
#     Recompra (PL%)  Volume Operado (PL%)  Caixa/Disponibilidades (%PL)
# 21        0.570919             49.436773                      7.948443

# %%
csv[1].loc[csv[1]["FIDC"] == fidc, cols_to_verify]

# Mar
# Out:
#         PL Total     PL Sênior  PL Subordinada Jr  Subordinação (%)  \
# 20  9.535962e+08  5.458821e+08       2.970226e+08         42.755418
#
#     Subordinação Jr (%)  PDD Total (PL%)  Vencidos Total (PL%)  Prazo Médio  \
# 20             31.14763         1.884621              6.470884          NaN
#
#     Taxa Média  Concentração Maior Cedente (PL%)  \
# 20         NaN                          5.632003
#
#     Concentração Maior Sacado (PL%)  Concentração 10 Maiores Cedentes (PL%)  \
# 20                         2.826049                               30.599723
#
#     Concentração 10 Maiores Sacados (PL%)  Quantidade de Cedentes  \
# 20                               14.64575                   324.0
#
#     Quantidade de Sacados  Liquidados Total (PL%)  Duplicata (PL%)  \
# 20                 8925.0                     NaN        75.568347
#
#     Recompra (PL%)  Volume Operado (PL%)  Caixa/Disponibilidades (%PL)
# 20        0.133401             43.728642                     16.117134

# %%
csv[2].loc[csv[2]["FIDC"] == fidc, cols_to_verify]

# Abr
# Out:
#         PL Total     PL Sênior  PL Subordinada Jr  Subordinação (%)  \
# 19  9.666698e+08  5.515158e+08       3.029794e+08         42.946824
#
#     Subordinação Jr (%)  PDD Total (PL%)  Vencidos Total (PL%)  Prazo Médio  \
# 19            31.342592         1.626089              8.028664          NaN
#
#     Taxa Média  Concentração Maior Cedente (PL%)  \
# 19         NaN                          5.105885
#
#     Concentração Maior Sacado (PL%)  Concentração 10 Maiores Cedentes (PL%)  \
# 19                         2.957832                               31.654507
#
#     Concentração 10 Maiores Sacados (PL%)  Quantidade de Cedentes  \
# 19                              16.400306                   314.0
#
#     Quantidade de Sacados  Liquidados Total (PL%)  Duplicata (PL%)  \
# 19                 7954.0                     NaN        70.220883
#
#     Recompra (PL%)  Volume Operado (PL%)  Caixa/Disponibilidades (%PL)
# 19        0.292477             55.266482                     15.180896
