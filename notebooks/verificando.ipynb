# %%
import pandas as pd

# %%
csv = []
for i in range(2, 5):
    csv.append(pd.read_csv(f'../data/GROUPED/FIDCS_2025_0{i}_01.csv', delimiter=';'))

len(csv)
# Out:
# 3

# %%
cols_to_verify = ["PL Total", "PL Sênior", "PL Subordinada Jr", "Subordinação (%)",
                  "Subordinação Jr (%)", "PDD Total (PL%)", "CVNP (PL%)", "CVNP - PDD (PL%)",
                  "Prazo Médio", "Taxa Média", "Concentração Maior Cedente (PL%)",
                  "Concentração Maior Sacado (PL%)", "Concentração 10 Maiores Cedentes (PL%)",
                  "Concentração 10 Maiores Sacados (PL%)", "Quantidade de Cedentes",
                  "Quantidade de Sacados", "Liquidados Total (PL%)", "Duplicata (PL%)", "Duplicata (%)",
                  "Recompra (PL%)", "Volume Operado (PL%)", "Caixa/Disponibilidades (%PL)"]

# %%
fidc = "SABIA"

#Multiasset, sifraplus, sifrastars, barcelona em teoria, onix

# %%
csv[0].loc[csv[0]["FIDC"] == fidc, cols_to_verify]

# Fev
# Out:
#         PL Total    PL Sênior  PL Subordinada Jr  Subordinação (%)  \
# 21  1.859019e+08  90009684.37        60707900.77         51.582154
#
#     Subordinação Jr (%)  PDD Total (PL%)  CVNP (PL%)  CVNP - PDD (PL%)  \
# 21            32.655883         1.512796    9.946868          8.434072
#
#     Prazo Médio  Taxa Média  ...  Concentração Maior Sacado (PL%)  \
# 21    57.273299    0.024285  ...                         2.969002
#
#     Concentração 10 Maiores Cedentes (PL%)  \
# 21                               47.966548
#
#     Concentração 10 Maiores Sacados (PL%)  Quantidade de Cedentes  \
# 21                              23.439569                   105.0
#
#     Quantidade de Sacados  Liquidados Total (PL%)  Duplicata (PL%)  \
# 21                  795.0                     NaN        64.411734
#
#     Recompra (PL%)  Volume Operado (PL%)  Caixa/Disponibilidades (%PL)
# 21         3.98831             54.460443                      1.211685
#
# [1 rows x 21 columns]

# %%
csv[1].loc[csv[1]["FIDC"] == fidc, cols_to_verify]

# Mar
# Out:
#         PL Total    PL Sênior  PL Subordinada Jr  Subordinação (%)  \
# 20  1.907391e+08  93002733.61        62085710.75         51.240854
#
#     Subordinação Jr (%)  PDD Total (PL%)  CVNP (PL%)  CVNP - PDD (PL%)  \
# 20            32.550078         1.627056   12.120377         10.493321
#
#     Prazo Médio  Taxa Média  ...  Concentração Maior Sacado (PL%)  \
# 20     55.25164    0.022747  ...                             3.02
#
#     Concentração 10 Maiores Cedentes (PL%)  \
# 20                               41.864396
#
#     Concentração 10 Maiores Sacados (PL%)  Quantidade de Cedentes  \
# 20                              21.410869                   119.0
#
#     Quantidade de Sacados  Liquidados Total (PL%)  Duplicata (PL%)  \
# 20                  990.0                     NaN         65.62841
#
#     Recompra (PL%)  Volume Operado (PL%)  Caixa/Disponibilidades (%PL)
# 20        3.770077             59.387222                      1.759258
#
# [1 rows x 21 columns]

# %%
csv[2].loc[csv[2]["FIDC"] == fidc, cols_to_verify]

# Abr
# Out:
# Empty DataFrame
# Columns: [PL Total, PL Sênior, PL Subordinada Jr, Subordinação (%), Subordinação Jr (%), PDD Total (PL%), CVNP (PL%), CVNP - PDD (PL%), Prazo Médio, Taxa Média, Concentração Maior Cedente (PL%), Concentração Maior Sacado (PL%), Concentração 10 Maiores Cedentes (PL%), Concentração 10 Maiores Sacados (PL%), Quantidade de Cedentes, Quantidade de Sacados, Liquidados Total (PL%), Duplicata (PL%), Recompra (PL%), Volume Operado (PL%), Caixa/Disponibilidades (%PL)]
# Index: []
#
# [0 rows x 21 columns]
