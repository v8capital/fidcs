# %%
import pandas as pd
import numpy as np

# %%
teste = ExcelTransformer("..\data\RAW\FIDC_FIRMA_2025_03_01.xlsx", "FIRMA")
# Out:
# 2025-07-08 15:33:46,134 - INFO - classes.logger - _check_name - Nome FIRMA encontrado.
# 2025-07-08 15:33:46,266 - INFO - classes.logger - __init__ - FIDC FIRMA da Gestora FIRMA carregado com sucesso.

# %%
teste.transform_table("../data")
# Out:
#     0    1           2    3                    4            5    \
# 0   NaN  NaN         NaN  NaN                  NaN          NaN
# 1   NaN  NaN         NaN  NaN                 Item     PL Total
# 2   NaN  NaN         NaN  NaN  2021-12-01 00:00:00  11280298.87
# 3   NaN  NaN         NaN  NaN  2022-01-01 00:00:00  12466910.85
# 4   NaN  NaN         NaN  NaN  2022-02-01 00:00:00   13673103.9
# 5   NaN  NaN         NaN  NaN  2022-03-01 00:00:00  13931632.28
# 6   NaN  NaN         NaN  NaN  2022-04-01 00:00:00  14140683.97
# 7   NaN  NaN         NaN  NaN  2022-05-01 00:00:00  14342965.01
# 8   NaN  NaN         NaN  NaN  2022-06-01 00:00:00  14470527.23
# 9   NaN  NaN         NaN  NaN  2022-07-01 00:00:00  14625899.21
# 10  NaN  NaN         NaN  NaN  2022-08-01 00:00:00  14541988.45
# 11  NaN  NaN         NaN  NaN  2022-09-01 00:00:00  18863461.89
# 12  NaN  NaN         NaN  NaN  2022-10-01 00:00:00  21063054.59
# 13  NaN  NaN         NaN  NaN  2022-11-01 00:00:00  22555353.07
# ...

# %%
# quase perfeito
