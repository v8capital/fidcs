# %%
import pandas as pd
import numpy as np

# %%
teste = pd.read_excel("../data/RAW/FIDC_RAM_2024_12_01.xlsx")

teste
# Out:
#     Unnamed: 0                               Unnamed: 1           Unnamed: 2  \
# 0          NaN                                      NaN                  NaN
# 1          NaN                                     Item  2021-07-31 00:00:00
# 2          NaN                                 PL Total          33178879.19
# 3          NaN                                PL Sênior                    0
# 4          NaN                              PL Mezanino                    0
# 5          NaN                       PL Subordinada Jr.          33178879.19
# 6          NaN                                      NaN                  NaN
# 7          NaN                Rentabilidade Subordinada             0.013738
# 8          NaN  Rentabilidade Subordinada Junior (%CDI)             5.314274
# 9          NaN                      Subordinação Junior                    1
# 10         NaN                    Subordinação Mezanino                    0
# ...

# %%
df = teste.iloc[3:, 3:]

df
# Out:
#      Unnamed: 3      Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7  \
# 3             0      3633824.06    4689739.44     4735225.5    6301995.54
# 4             0      4220641.21    5615676.51    5675521.78    8788036.61
# 5   34224445.08     41012065.34   41398578.36   47153257.01   47966904.24
# 6           NaN             NaN           NaN           NaN           NaN
# 7      0.012943        0.013119      0.011198      0.013265      0.017255
# 8      3.051674        2.993616      2.330975      2.260751      2.259889
# 9             1        0.839267      0.800684      0.819145      0.760692
# 10            0        0.086371      0.108612      0.098595      0.139367
# 11            1        0.925638      0.909296       0.91774      0.900059
# 12            0  3619999.999961             0             0       1500000
# 13            0  4200004.680573       1350000             0       3000000
# 14       613835   6299999.99998       1020000       5100000             0
# ...

# %%
for col in df.columns:
    for idx, val in df[col].items():
        if isinstance(val, pd.NaT.__class__):  # somente NaT, não NaN
            print(f"NaT encontrado → Linha: {idx}, Coluna: '{col}', Valor: {val}")
